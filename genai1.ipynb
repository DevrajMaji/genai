# %% [markdown]
# Question 1: What is Generative AI and what are its primary use cases across
# industries?
#
# ->Generative AI is a type of Artificial Intelligence that can create new content such as text, images, audio, video, or code by learning patterns from data.
#
# Primary Use Cases Across Industries:
#
# Healthcare: medical reports, drug discovery
#
# Finance: fraud detection, financial analysis
#
# Marketing: content creation, ads, product descriptions
#
# Software Development: automatic code generation (e.g., GitHub Copilot)
#
# Media & Entertainment: image, music, and video generation (e.g., DALL·E)
#
# Education: AI tutors, learning materials
#
# Customer Support: chatbots and virtual assistants
#
# Question 2: Explain the role of probabilistic modeling in generative models. How do these models differ from discriminative models?
#
# ->Probabilistic modeling in generative models:
# Generative models use probability distributions to learn how data is generated. They model the joint probability
# 𝑃
# (
# 𝑋
# ,
# 𝑌
# )
# P(X,Y) or the data distribution
# 𝑃
# (
# 𝑋
# )
# P(X) and then generate new data samples similar to the training data.
#
# Example:
# Models like GAN and Variational Autoencoder learn the probability distribution of the data and generate new images, text, etc.
#
# Difference between Generative and Discriminative models:
#
# Generative Models:
# Learn how data is generated and model
# 𝑃
# (
# 𝑋
# ,
# 𝑌
# )
# P(X,Y).
# Can generate new data.
#
# Discriminative Models:
# Learn the decision boundary between classes and model
# 𝑃
# (
# 𝑌
# ∣
# 𝑋
# )
# P(Y∣X).
# Used mainly for classification or prediction.
#
# Question 3: What is the difference between Autoencoders and Variational
# Autoencoders (VAEs) in the context of text generation?
#
# ->Autoencoders:
# They learn to compress text into a hidden representation and then reconstruct the same text. They mainly focus on reconstruction, not generating new text.
#
# Variational Autoencoders (VAEs):
# They learn a probability distribution of the latent space, so they can generate new text samples, not just reconstruct the input.
#
# Example: Variational Autoencoder
#
# Key Difference:
#
# Autoencoder: reconstructs the same input text.
#
# VAE: learns a distribution and generates new text from it.
#
# Question 4: Describe the working of attention mechanisms in Neural Machine
# Translation (NMT). Why are they critical?
#
# ->In Neural Machine Translation, the attention mechanism helps the model focus on important words of the input sentence while translating.
#
# How it works:
#
# The encoder processes the input sentence.
#
# During translation, the decoder looks at different parts of the input sentence.
#
# Attention gives higher weight to the most relevant words for generating the next word.
#
# Example: Models like Transformer use attention for translation.
#
# Why it is critical:
#
# Handles long sentences better
#
# Improves translation accuracy
#
# Allows the model to focus on relevant words during translation.
#
# Question 5: What ethical considerations must be addressed when using generative AI for creative content such as poetry or storytelling?
#
# ->thical considerations in Generative AI for creative content:
#
# Copyright issues: AI may generate content similar to existing works.
#
# Plagiarism: Risk of copying original authors’ style or text.
#
# Bias: AI can produce biased or unfair content if training data is biased.
#
# Misinformation: AI-generated stories or text may spread false information.
#
# Authorship: It can be unclear whether the human or AI should get credit.

# %%
'''Question 6: Use the following small text dataset to train a simple Variational
Autoencoder (VAE) for text reconstruction:
["The sky is blue", "The sun is bright", "The grass is green",
"The night is dark", "The stars are shining"]
1. Preprocess the data (tokenize and pad the sequences).
2. Build a basic VAE model for text reconstruction.
3. Train the model and show how it reconstructs or generates similar sentences.
Include your code, explanation, and sample outputs'''

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

sentences = [
"The sky is blue",
"The sun is bright",
"The grass is green",
"The night is dark",
"The stars are shining"
]


tokenizer = Tokenizer()
tokenizer.fit_on_texts(sentences)

sequences = tokenizer.texts_to_sequences(sentences)


max_len = max(len(seq) for seq in sequences)
padded_sequences = pad_sequences(sequences, maxlen=max_len, padding='post')

vocab_size = len(tokenizer.word_index) + 1

print(padded_sequences)
# Out:
# [[ 1  3  2  4]
#  [ 1  5  2  6]
#  [ 1  7  2  8]
#  [ 1  9  2 10]
#  [ 1 11 12 13]]

# %%
'''Question 7: Use a pre-trained GPT model (like GPT-2 or GPT-3) to translate a short
English paragraph into French and German. Provide the original and translated text'''

from openai import OpenAI

# Initialize client with API key
client = OpenAI(api_key="api key")

text = "Artificial intelligence is transforming the world. It helps people solve complex problems, improve healthcare, and create new technologies for the future."

prompt = f"""
Translate the following English paragraph into French and German.

English:
{text}

Give the translations clearly.
"""

response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "user", "content": prompt}
    ]
)

print(response.choices[0].message.content)

# %%
'''Question 8: Implement a simple attention-based encoder-decoder model for
English-to-Spanish translation using Tensorflow or PyTorch.'''

import tensorflow as tf
import numpy as np
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense, Attention
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

eng = ["hello", "how are you", "good morning", "thank you"]
spa = ["hola", "como estas", "buenos dias", "gracias"]

tok_eng = Tokenizer()
tok_spa = Tokenizer()

tok_eng.fit_on_texts(eng)
tok_spa.fit_on_texts(spa)

eng_seq = tok_eng.texts_to_sequences(eng)
spa_seq = tok_spa.texts_to_sequences(spa)

max_len = max(max(len(i) for i in eng_seq), max(len(i) for i in spa_seq))

eng_seq = pad_sequences(eng_seq, maxlen=max_len, padding="post")
spa_seq = pad_sequences(spa_seq, maxlen=max_len, padding="post")

vocab_eng = len(tok_eng.word_index) + 1
vocab_spa = len(tok_spa.word_index) + 1

encoder_inputs = Input(shape=(max_len,))
enc_emb = Embedding(vocab_eng, 64)(encoder_inputs)
encoder_lstm = LSTM(64, return_sequences=True)
encoder_outputs = encoder_lstm(enc_emb)

attention = Attention()
attention_output = attention([encoder_outputs, encoder_outputs])

decoder_lstm = LSTM(64, return_sequences=True)
decoder_outputs = decoder_lstm(attention_output)

outputs = Dense(vocab_spa, activation="softmax")(decoder_outputs)

model = tf.keras.Model(encoder_inputs, outputs)

model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

model.fit(eng_seq, np.expand_dims(spa_seq, -1), epochs=200)

test = tok_eng.texts_to_sequences(["hello"])
test = pad_sequences(test, maxlen=max_len, padding="post")

pred = model.predict(test)

pred_ids = np.argmax(pred[0], axis=1)

reverse_spa = {v:k for k,v in tok_spa.word_index.items()}

translated = " ".join([reverse_spa.get(i,"") for i in pred_ids if i!=0])

print("Input:", "hello")
print("Predicted Spanish:", translated)
# Out:
# Epoch 1/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.1667 - loss: 1.9458
# Epoch 2/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 599ms/step - accuracy: 0.5000 - loss: 1.9416
# Epoch 3/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.5000 - loss: 1.9373
# Epoch 4/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.5000 - loss: 1.9327
# Epoch 5/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.5000 - loss: 1.9279
# Epoch 6/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.5000 - loss: 1.9227
# Epoch 7/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.5000 - loss: 1.9170
# Epoch 8/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.5000 - loss: 1.9108
# Epoch 9/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.5000 - loss: 1.9040
# Epoch 10/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.5000 - loss: 1.8964
# Epoch 11/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.5000 - loss: 1.8879
# Epoch 12/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.5000 - loss: 1.8784
# Epoch 13/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.5000 - loss: 1.8678
# Epoch 14/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.5000 - loss: 1.8558
# Epoch 15/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.5000 - loss: 1.8423
# Epoch 16/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.5000 - loss: 1.8270
# Epoch 17/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.5000 - loss: 1.8097
# Epoch 18/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.5000 - loss: 1.7900
# Epoch 19/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.5000 - loss: 1.7676
# Epoch 20/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.5000 - loss: 1.7422
# Epoch 21/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.5000 - loss: 1.7132
# Epoch 22/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - accuracy: 0.5000 - loss: 1.6804
# Epoch 23/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.5000 - loss: 1.6434
# Epoch 24/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.5000 - loss: 1.6018
# Epoch 25/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.5000 - loss: 1.5557
# Epoch 26/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.5000 - loss: 1.5054
# Epoch 27/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.5000 - loss: 1.4520
# Epoch 28/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.5000 - loss: 1.3976
# Epoch 29/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.5000 - loss: 1.3454
# Epoch 30/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.5000 - loss: 1.2997
# Epoch 31/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.5000 - loss: 1.2650
# Epoch 32/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.5000 - loss: 1.2446
# Epoch 33/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.5000 - loss: 1.2386
# Epoch 34/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.5000 - loss: 1.2437
# Epoch 35/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - accuracy: 0.5000 - loss: 1.2538
# Epoch 36/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.5000 - loss: 1.2625
# Epoch 37/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.5000 - loss: 1.2655
# Epoch 38/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.5000 - loss: 1.2616
# Epoch 39/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.5000 - loss: 1.2515
# Epoch 40/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.5000 - loss: 1.2373
# Epoch 41/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.5000 - loss: 1.2214
# Epoch 42/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.5000 - loss: 1.2059
# Epoch 43/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.5000 - loss: 1.1924
# Epoch 44/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.5000 - loss: 1.1816
# Epoch 45/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.5000 - loss: 1.1738
# Epoch 46/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.5000 - loss: 1.1687
# Epoch 47/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.5000 - loss: 1.1658
# Epoch 48/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.5000 - loss: 1.1643
# Epoch 49/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.5000 - loss: 1.1635
# Epoch 50/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.5000 - loss: 1.1627
# Epoch 51/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.5000 - loss: 1.1615
# Epoch 52/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.5000 - loss: 1.1596
# Epoch 53/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.5000 - loss: 1.1569
# Epoch 54/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.5000 - loss: 1.1535
# Epoch 55/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5000 - loss: 1.1494
# Epoch 56/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.5000 - loss: 1.1448
# Epoch 57/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.5000 - loss: 1.1401
# Epoch 58/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.5000 - loss: 1.1354
# Epoch 59/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.5000 - loss: 1.1309
# Epoch 60/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.5000 - loss: 1.1268
# Epoch 61/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.5000 - loss: 1.1232
# Epoch 62/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.5000 - loss: 1.1200
# Epoch 63/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.5000 - loss: 1.1171
# Epoch 64/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.5000 - loss: 1.1145
# Epoch 65/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.5000 - loss: 1.1119
# Epoch 66/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.5000 - loss: 1.1093
# Epoch 67/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.5000 - loss: 1.1064
# Epoch 68/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.5000 - loss: 1.1032
# Epoch 69/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.5000 - loss: 1.0998
# Epoch 70/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.5000 - loss: 1.0961
# Epoch 71/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.5000 - loss: 1.0922
# Epoch 72/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.5000 - loss: 1.0883
# Epoch 73/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.5000 - loss: 1.0843
# Epoch 74/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.5000 - loss: 1.0803
# Epoch 75/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - accuracy: 0.5000 - loss: 1.0764
# Epoch 76/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.5000 - loss: 1.0726
# Epoch 77/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.5000 - loss: 1.0688
# Epoch 78/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.5000 - loss: 1.0650
# Epoch 79/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.5000 - loss: 1.0610
# Epoch 80/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.5000 - loss: 1.0570
# Epoch 81/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.5000 - loss: 1.0528
# Epoch 82/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.5000 - loss: 1.0484
# Epoch 83/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.5000 - loss: 1.0438
# Epoch 84/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.5000 - loss: 1.0391
# Epoch 85/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.5000 - loss: 1.0341
# Epoch 86/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.5000 - loss: 1.0290
# Epoch 87/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.5000 - loss: 1.0236
# Epoch 88/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.5000 - loss: 1.0181
# Epoch 89/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.5000 - loss: 1.0125
# Epoch 90/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.5000 - loss: 1.0066
# Epoch 91/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.5000 - loss: 1.0005
# Epoch 92/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.5000 - loss: 0.9942
# Epoch 93/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.5000 - loss: 0.9877
# Epoch 94/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.5000 - loss: 0.9809
# Epoch 95/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.5000 - loss: 0.9738
# Epoch 96/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.5000 - loss: 0.9665
# Epoch 97/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.5000 - loss: 0.9589
# Epoch 98/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.5000 - loss: 0.9511
# Epoch 99/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.5000 - loss: 0.9431
# Epoch 100/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.5833 - loss: 0.9349
# Epoch 101/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.5833 - loss: 0.9266
# Epoch 102/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.5833 - loss: 0.9181
# Epoch 103/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.5833 - loss: 0.9096
# Epoch 104/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.5833 - loss: 0.9010
# Epoch 105/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.5833 - loss: 0.8924
# Epoch 106/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.5833 - loss: 0.8837
# Epoch 107/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.5833 - loss: 0.8752
# Epoch 108/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.5833 - loss: 0.8666
# Epoch 109/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.5833 - loss: 0.8581
# Epoch 110/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.5833 - loss: 0.8497
# Epoch 111/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.5833 - loss: 0.8413
# Epoch 112/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - accuracy: 0.5833 - loss: 0.8329
# Epoch 113/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.5833 - loss: 0.8246
# Epoch 114/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.5833 - loss: 0.8162
# Epoch 115/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.5833 - loss: 0.8078
# Epoch 116/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.5833 - loss: 0.7993
# Epoch 117/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.5833 - loss: 0.7909
# Epoch 118/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.5833 - loss: 0.7826
# Epoch 119/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.5833 - loss: 0.7742
# Epoch 120/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.5833 - loss: 0.7659
# Epoch 121/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.5833 - loss: 0.7576
# Epoch 122/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.5833 - loss: 0.7493
# Epoch 123/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.5833 - loss: 0.7409
# Epoch 124/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.5833 - loss: 0.7324
# Epoch 125/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.5833 - loss: 0.7238
# Epoch 126/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.5833 - loss: 0.7151
# Epoch 127/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.5833 - loss: 0.7063
# Epoch 128/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.5833 - loss: 0.6974
# Epoch 129/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.5833 - loss: 0.6883
# Epoch 130/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.5833 - loss: 0.6792
# Epoch 131/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.6667 - loss: 0.6700
# Epoch 132/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.6667 - loss: 0.6605
# Epoch 133/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.6667 - loss: 0.6509
# Epoch 134/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.6667 - loss: 0.6411
# Epoch 135/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.6667 - loss: 0.6311
# Epoch 136/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.6667 - loss: 0.6209
# Epoch 137/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.6667 - loss: 0.6106
# Epoch 138/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.7500 - loss: 0.6002
# Epoch 139/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.7500 - loss: 0.5897
# Epoch 140/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.7500 - loss: 0.5790
# Epoch 141/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.7500 - loss: 0.5681
# Epoch 142/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.8333 - loss: 0.5570
# Epoch 143/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.8333 - loss: 0.5457
# Epoch 144/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.8333 - loss: 0.5343
# Epoch 145/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.8333 - loss: 0.5227
# Epoch 146/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.8333 - loss: 0.5110
# Epoch 147/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.8333 - loss: 0.4992
# Epoch 148/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.8333 - loss: 0.4873
# Epoch 149/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8333 - loss: 0.4753
# Epoch 150/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.8333 - loss: 0.4634
# Epoch 151/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8333 - loss: 0.4515
# Epoch 152/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.8333 - loss: 0.4397
# Epoch 153/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.8333 - loss: 0.4281
# Epoch 154/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.8333 - loss: 0.4165
# Epoch 155/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.8333 - loss: 0.4052
# Epoch 156/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8333 - loss: 0.3940
# Epoch 157/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8333 - loss: 0.3830
# Epoch 158/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.8333 - loss: 0.3722
# Epoch 159/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.8333 - loss: 0.3615
# Epoch 160/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8333 - loss: 0.3509
# Epoch 161/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9167 - loss: 0.3404
# Epoch 162/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.9167 - loss: 0.3298
# Epoch 163/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.9167 - loss: 0.3193
# Epoch 164/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.9167 - loss: 0.3086
# Epoch 165/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9167 - loss: 0.2977
# Epoch 166/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.9167 - loss: 0.2866
# Epoch 167/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.9167 - loss: 0.2754
# Epoch 168/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9167 - loss: 0.2641
# Epoch 169/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9167 - loss: 0.2528
# Epoch 170/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 1.0000 - loss: 0.2415
# Epoch 171/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 1.0000 - loss: 0.2303
# Epoch 172/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.2193
# Epoch 173/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.2086
# Epoch 174/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.1980
# Epoch 175/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 1.0000 - loss: 0.1878
# Epoch 176/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 1.0000 - loss: 0.1778
# Epoch 177/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 1.0000 - loss: 0.1681
# Epoch 178/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 1.0000 - loss: 0.1587
# Epoch 179/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 1.0000 - loss: 0.1495
# Epoch 180/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 1.0000 - loss: 0.1406
# Epoch 181/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 1.0000 - loss: 0.1321
# Epoch 182/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 1.0000 - loss: 0.1239
# Epoch 183/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 1.0000 - loss: 0.1161
# Epoch 184/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 1.0000 - loss: 0.1087
# Epoch 185/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 0.1018
# Epoch 186/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 1.0000 - loss: 0.0954
# Epoch 187/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 1.0000 - loss: 0.0894
# Epoch 188/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 1.0000 - loss: 0.0839
# Epoch 189/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.0788
# Epoch 190/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0741
# Epoch 191/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 1.0000 - loss: 0.0697
# Epoch 192/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 1.0000 - loss: 0.0657
# Epoch 193/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.0620
# Epoch 194/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.0586
# Epoch 195/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 1.0000 - loss: 0.0554
# Epoch 196/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 0.0525
# Epoch 197/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 1.0000 - loss: 0.0497
# Epoch 198/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 1.0000 - loss: 0.0472
# Epoch 199/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 1.0000 - loss: 0.0448
# Epoch 200/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 1.0000 - loss: 0.0427
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 640ms/step
# Input: hello
# Predicted Spanish: hola

# %%
'''Question 9: Use the following short poetry dataset to simulate poem generation with a
pre-trained GPT model:
["Roses are red, violets are blue,",
"Sugar is sweet, and so are you.",
"The moon glows bright in silent skies,",
"A bird sings where the soft wind sighs."]
Using this dataset as a reference for poetic structure and language, generate a new 2-4
line poem using a pre-trained GPT model (such as GPT-2). You may simulate
fine-tuning by prompting the model with similar poetic patterns.
Include your code, the prompt used, and the generated poem in your answer.
'''

from transformers import pipeline

poetry_dataset = [
"Roses are red, violets are blue,",
"Sugar is sweet, and so are you.",
"The moon glows bright in silent skies,",
"A bird sings where the soft wind sighs."
]

prompt = """
Roses are red, violets are blue,
Sugar is sweet, and so are you.
The moon glows bright in silent skies,
A bird sings where the soft wind sighs.

Write a new short poem in the same style:
"""

generator = pipeline("text-generation", model="gpt2")

result = generator(prompt, max_length=60, num_return_sequences=1)

print("Prompt:")
print(prompt)

print("\nGenerated Poem:")
print(result[0]["generated_text"])
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Passing `generation_config` together with generation-related arguments=({'num_return_sequences', 'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=60) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Prompt:
#
# Roses are red, violets are blue,
# Sugar is sweet, and so are you.
# The moon glows bright in silent skies,
# A bird sings where the soft wind sighs.
#
# Write a new short poem in the same style:
#
#
# Generated Poem:
#
# Roses are red, violets are blue,
# Sugar is sweet, and so are you.
# The moon glows bright in silent skies,
# A bird sings where the soft wind sighs.
#
# Write a new short poem in the same style:
#
# Your poem will never be forgotten
#
# A poem that keeps me on my toes
#
# And I never know how it will end.
#
# Your poem will never be forgotten
#
# A poem that keeps me on my toes
#
# And I never know how it will end.
#
# It's a piece of poetry, but it's not a poem. It's a poem that's already written.
#
# I'm writing this poem, you're writing it.
#
# I'm writing this poem, you're writing it.
#
# It's a piece of poetry, but it's not a poem. It's a poem that's already written.
#
# My poem is already written. I'm writing this poem, you're writing it.
#
# I'm writing this poem, you're writing it.
#
# If I can stop writing,
#
# If I can stop writing,
#
# If I can stop writing,
#
# If I can stop writing,
#
# I'm writing this poem, you're writing it.
#
# I'm writing this poem, you're writing it.
#
# It's a poem, but it's not a poem. It's a poem that's already written.
#
# I'm writing this poem, you're

# %%
'''Question 10: Imagine you are building a creative writing assistant for a publishing
company. The assistant should generate story plots and character descriptions using
Generative AI. Describe how you would design the system, including model selection,
training data, bias mitigation, and evaluation methods. Explain the real-world challenges
you might face.'''

'''1. Model Selection
Use a large language model such as GPT-3 or GPT-2 because they are good at generating natural language, story plots, and character descriptions.

2. Training Data
The model would be trained or fine-tuned on:

Books and novels

Short stories and scripts

Character descriptions and plot summaries
This helps the model learn narrative structure, storytelling style, and character development.

3. Bias Mitigation
To reduce bias:

Use diverse datasets from different cultures and authors

Remove harmful or biased text from training data

Apply moderation filters to generated content.

4. Evaluation Methods
The system can be evaluated by:

Human evaluation (editors reviewing story quality)

Coherence and creativity checks

Relevance to the prompt

User feedback from writers and editors.

5. Real-World Challenges

Copyright issues if generated text resembles existing books

Bias in generated stories

Maintaining creativity without repeating patterns

Large computational cost for training and inference

Ensuring ethical and responsible content generation.'''


from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

prompt = """
Create a story plot and main character description.

Story Genre: Fantasy

Character:
Name:
Background:
Personality:

Story Plot:
"""

result = generator(prompt, max_length=150, num_return_sequences=1)

print(result[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=150) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Create a story plot and main character description.
#
# Story Genre: Fantasy
#
# Character:
# Name:
# Background:
# Personality:
#
# Story Plot:
#
# Main Characters:
#
# Main Story Subtitles:
#
# The main character is an ordinary girl who tries to do good things for her family. After her father dies, she helps her father find the time to go to the beach and stay with her grandparents. She also finds a place to live and help her grandparents find a new home. Her character description is quite interesting and has some interesting twists and turns.
#
# The main character is an ordinary girl who tries to do good things for her family. After her father dies, she helps her father find the time to go to the beach and stay with her grandparents. She also finds a place to live and help her grandparents find a new home. Her character description is quite interesting and has some interesting twists and turns.
#
# Characters:
#
# Main Story Subtitles:
#
# Characters:
#
# Character Name:
#
# Character Character Character Status:
#
# Main Character:
#
# Character Character Character Status:
#
# Main Story Subtitles:
#
# Character Character Character Status:
#
# Main Story Subtitles:
#
# Character Character Character Status:
#
# Main Story Subtitles:
#
# Character Character Character Status:
#
# Main Story Subtitles:
#
# Character Character Character Status:
